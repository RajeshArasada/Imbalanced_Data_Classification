# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import imblearn
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Data

# %%
first_counter_OHE = pd.read_csv("../data/processed/first_encounter_OHE.csv")
first_counter_OHE.sample(5)
# Out:
#        number_diagnoses_clip  number_outpatient_log1p  number_emergency_log1p  \
# 60882                      4                 0.000000                     0.0
# 62169                      9                 0.000000                     0.0
# 63416                      9                 0.000000                     0.0
# 69138                      9                 1.098612                     0.0
# 37191                      9                 0.000000                     0.0
#
#        number_inpatient_log1p  num_procedures_log1p  num_medications_log1p  \
# 60882                     0.0              0.000000               1.609438
# 62169                     0.0              0.693147               2.397895
# 63416                     0.0              0.693147               2.772589
# 69138                     0.0              0.000000               2.484907
# 37191                     0.0              0.693147               3.178054
#
#        num_lab_procedures_log1p  norm_time_in_hospital  readmitted_rescaled  \
# 60882                  1.386294              -1.115266                    0
# 62169                  2.639057              -0.437113                    0
# 63416                  3.713572              -0.437113                    0
# 69138                  1.386294              -0.098037                    1
# 37191                  4.174387              -0.437113                    0
#
#        race_AfricanAmerican  ...  grouped_diag_3_E8  grouped_diag_3_E9  \
# 60882                     0  ...                  0                  0
# 62169                     1  ...                  0                  0
# 63416                     0  ...                  0                  0
# 69138                     0  ...                  0                  0
# 37191                     0  ...                  0                  0
#
#        grouped_diag_3_V0  grouped_diag_3_V1  grouped_diag_3_V2  \
# 60882                  0                  0                  0
# 62169                  0                  0                  0
# 63416                  0                  0                  0
# 69138                  0                  0                  0
# 37191                  0                  0                  0
#
#        grouped_diag_3_V4  grouped_diag_3_V5  grouped_diag_3_V6  \
# 60882                  0                  0                  0
# 62169                  0                  0                  0
# 63416                  0                  0                  0
# 69138                  0                  0                  0
# 37191                  0                  0                  0
#
#        grouped_diag_3_V7  grouped_diag_3_V8
# 60882                  0                  0
# 62169                  0                  0
# 63416                  0                  0
# 69138                  0                  0
# 37191                  0                  0
#
# [5 rows x 382 columns]

# %%
first_counter_OHE.columns.tolist()
# Out:
# ['number_diagnoses_clip',
#  'number_outpatient_log1p',
#  'number_emergency_log1p',
#  'number_inpatient_log1p',
#  'num_procedures_log1p',
#  'num_medications_log1p',
#  'num_lab_procedures_log1p',
#  'norm_time_in_hospital',
#  'readmitted_rescaled',
#  'race_AfricanAmerican',
#  'race_Asian',
#  'race_Caucasian',
#  'race_Hispanic',
#  'race_Other',
#  'gender_Male',
#  'gender_Unknown/Invalid',
#  'age_[10-20)',
#  'age_[20-30)',
#  'age_[30-40)',
#  'age_[40-50)',
#  'age_[50-60)',
#  'age_[60-70)',
#  'age_[70-80)',
#  'age_[80-90)',
#  'age_[90-100)',
#  'metformin_No',
#  'metformin_Steady',
#  'metformin_Up',
#  'repaglinide_No',
#  'repaglinide_Steady',
#  'repaglinide_Up',
#  'nateglinide_No',
#  'nateglinide_Steady',
#  'nateglinide_Up',
#  'chlorpropamide_No',
#  'chlorpropamide_Steady',
#  'chlorpropamide_Up',
#  'glimepiride_No',
#  'glimepiride_Steady',
#  'glimepiride_Up',
#  'glipizide_No',
#  'glipizide_Steady',
#  'glipizide_Up',
#  'glyburide_No',
#  'glyburide_Steady',
#  'glyburide_Up',
#  'tolbutamide_Steady',
#  'pioglitazone_No',
#  'pioglitazone_Steady',
#  'pioglitazone_Up',
#  'rosiglitazone_No',
#  'rosiglitazone_Steady',
#  'rosiglitazone_Up',
#  'acarbose_Steady',
#  'acarbose_Up',
#  'miglitol_No',
#  'miglitol_Steady',
#  'miglitol_Up',
#  'tolazamide_Steady',
#  'insulin_No',
#  'insulin_Steady',
#  'insulin_Up',
#  'glyburide-metformin_No',
#  'glyburide-metformin_Steady',
#  'glyburide-metformin_Up',
#  'glipizide-metformin_Steady',
#  'change_No',
#  'diabetesMed_Yes',
#  'grouped_diag_1_00',
#  'grouped_diag_1_01',
#  'grouped_diag_1_02',
#  'grouped_diag_1_03',
#  'grouped_diag_1_04',
#  'grouped_diag_1_05',
#  'grouped_diag_1_06',
#  'grouped_diag_1_07',
#  'grouped_diag_1_08',
#  'grouped_diag_1_09',
#  'grouped_diag_1_11',
#  'grouped_diag_1_13',
#  'grouped_diag_1_14',
#  'grouped_diag_1_15',
#  'grouped_diag_1_16',
#  'grouped_diag_1_17',
#  'grouped_diag_1_18',
#  'grouped_diag_1_19',
#  'grouped_diag_1_20',
#  'grouped_diag_1_21',
#  'grouped_diag_1_22',
#  'grouped_diag_1_23',
#  'grouped_diag_1_24',
#  'grouped_diag_1_25',
#  'grouped_diag_1_26',
#  'grouped_diag_1_27',
#  'grouped_diag_1_28',
#  'grouped_diag_1_29',
#  'grouped_diag_1_30',
#  'grouped_diag_1_31',
#  'grouped_diag_1_32',
#  'grouped_diag_1_33',
#  'grouped_diag_1_34',
#  'grouped_diag_1_35',
#  'grouped_diag_1_36',
#  'grouped_diag_1_37',
#  'grouped_diag_1_38',
#  'grouped_diag_1_39',
#  'grouped_diag_1_40',
#  'grouped_diag_1_41',
#  'grouped_diag_1_42',
#  'grouped_diag_1_43',
#  'grouped_diag_1_44',
#  'grouped_diag_1_45',
#  'grouped_diag_1_46',
#  'grouped_diag_1_47',
#  'grouped_diag_1_48',
#  'grouped_diag_1_49',
#  'grouped_diag_1_50',
#  'grouped_diag_1_51',
#  'grouped_diag_1_52',
#  'grouped_diag_1_53',
#  'grouped_diag_1_54',
#  'grouped_diag_1_55',
#  'grouped_diag_1_56',
#  'grouped_diag_1_57',
#  'grouped_diag_1_58',
#  'grouped_diag_1_59',
#  'grouped_diag_1_60',
#  'grouped_diag_1_61',
#  'grouped_diag_1_62',
#  'grouped_diag_1_63',
#  'grouped_diag_1_64',
#  'grouped_diag_1_65',
#  'grouped_diag_1_66',
#  'grouped_diag_1_67',
#  'grouped_diag_1_68',
#  'grouped_diag_1_69',
#  'grouped_diag_1_70',
#  'grouped_diag_1_71',
#  'grouped_diag_1_72',
#  'grouped_diag_1_73',
#  'grouped_diag_1_74',
#  'grouped_diag_1_75',
#  'grouped_diag_1_78',
#  'grouped_diag_1_79',
#  'grouped_diag_1_80',
#  'grouped_diag_1_81',
#  'grouped_diag_1_82',
#  'grouped_diag_1_83',
#  'grouped_diag_1_84',
#  'grouped_diag_1_85',
#  'grouped_diag_1_86',
#  'grouped_diag_1_87',
#  'grouped_diag_1_88',
#  'grouped_diag_1_89',
#  'grouped_diag_1_90',
#  'grouped_diag_1_91',
#  'grouped_diag_1_92',
#  'grouped_diag_1_93',
#  'grouped_diag_1_94',
#  'grouped_diag_1_95',
#  'grouped_diag_1_96',
#  'grouped_diag_1_97',
#  'grouped_diag_1_98',
#  'grouped_diag_1_99',
#  'grouped_diag_1_E9',
#  'grouped_diag_1_V2',
#  'grouped_diag_1_V4',
#  'grouped_diag_1_V5',
#  'grouped_diag_1_V6',
#  'grouped_diag_1_V7',
#  'grouped_diag_2_00',
#  'grouped_diag_2_01',
#  'grouped_diag_2_02',
#  'grouped_diag_2_03',
#  'grouped_diag_2_04',
#  'grouped_diag_2_05',
#  'grouped_diag_2_06',
#  'grouped_diag_2_07',
#  'grouped_diag_2_08',
#  'grouped_diag_2_09',
#  'grouped_diag_2_11',
#  'grouped_diag_2_12',
#  'grouped_diag_2_13',
#  'grouped_diag_2_14',
#  'grouped_diag_2_15',
#  'grouped_diag_2_16',
#  'grouped_diag_2_17',
#  'grouped_diag_2_18',
#  'grouped_diag_2_19',
#  'grouped_diag_2_20',
#  'grouped_diag_2_21',
#  'grouped_diag_2_22',
#  'grouped_diag_2_23',
#  'grouped_diag_2_24',
#  'grouped_diag_2_25',
#  'grouped_diag_2_26',
#  'grouped_diag_2_27',
#  'grouped_diag_2_28',
#  'grouped_diag_2_29',
#  'grouped_diag_2_30',
#  'grouped_diag_2_31',
#  'grouped_diag_2_32',
#  'grouped_diag_2_33',
#  'grouped_diag_2_34',
#  'grouped_diag_2_35',
#  'grouped_diag_2_36',
#  'grouped_diag_2_37',
#  'grouped_diag_2_38',
#  'grouped_diag_2_39',
#  'grouped_diag_2_40',
#  'grouped_diag_2_41',
#  'grouped_diag_2_42',
#  'grouped_diag_2_43',
#  'grouped_diag_2_44',
#  'grouped_diag_2_45',
#  'grouped_diag_2_46',
#  'grouped_diag_2_47',
#  'grouped_diag_2_48',
#  'grouped_diag_2_49',
#  'grouped_diag_2_50',
#  'grouped_diag_2_51',
#  'grouped_diag_2_52',
#  'grouped_diag_2_53',
#  'grouped_diag_2_54',
#  'grouped_diag_2_55',
#  'grouped_diag_2_56',
#  'grouped_diag_2_57',
#  'grouped_diag_2_58',
#  'grouped_diag_2_59',
#  'grouped_diag_2_60',
#  'grouped_diag_2_61',
#  'grouped_diag_2_62',
#  'grouped_diag_2_63',
#  'grouped_diag_2_64',
#  'grouped_diag_2_65',
#  'grouped_diag_2_66',
#  'grouped_diag_2_67',
#  'grouped_diag_2_68',
#  'grouped_diag_2_69',
#  'grouped_diag_2_70',
#  'grouped_diag_2_71',
#  'grouped_diag_2_72',
#  'grouped_diag_2_73',
#  'grouped_diag_2_74',
#  'grouped_diag_2_75',
#  'grouped_diag_2_78',
#  'grouped_diag_2_79',
#  'grouped_diag_2_80',
#  'grouped_diag_2_81',
#  'grouped_diag_2_82',
#  'grouped_diag_2_83',
#  'grouped_diag_2_84',
#  'grouped_diag_2_85',
#  'grouped_diag_2_86',
#  'grouped_diag_2_87',
#  'grouped_diag_2_88',
#  'grouped_diag_2_89',
#  'grouped_diag_2_90',
#  'grouped_diag_2_91',
#  'grouped_diag_2_92',
#  'grouped_diag_2_93',
#  'grouped_diag_2_94',
#  'grouped_diag_2_95',
#  'grouped_diag_2_96',
#  'grouped_diag_2_97',
#  'grouped_diag_2_98',
#  'grouped_diag_2_99',
#  'grouped_diag_2_E8',
#  'grouped_diag_2_E9',
#  'grouped_diag_2_V0',
#  'grouped_diag_2_V1',
#  'grouped_diag_2_V2',
#  'grouped_diag_2_V4',
#  'grouped_diag_2_V5',
#  'grouped_diag_2_V6',
#  'grouped_diag_2_V7',
#  'grouped_diag_2_V8',
#  'grouped_diag_3_00',
#  'grouped_diag_3_01',
#  'grouped_diag_3_02',
#  'grouped_diag_3_03',
#  'grouped_diag_3_04',
#  'grouped_diag_3_05',
#  'grouped_diag_3_06',
#  'grouped_diag_3_07',
#  'grouped_diag_3_09',
#  'grouped_diag_3_11',
#  'grouped_diag_3_12',
#  'grouped_diag_3_13',
#  'grouped_diag_3_14',
#  'grouped_diag_3_15',
#  'grouped_diag_3_16',
#  'grouped_diag_3_17',
#  'grouped_diag_3_18',
#  'grouped_diag_3_19',
#  'grouped_diag_3_20',
#  'grouped_diag_3_21',
#  'grouped_diag_3_22',
#  'grouped_diag_3_23',
#  'grouped_diag_3_24',
#  'grouped_diag_3_25',
#  'grouped_diag_3_26',
#  'grouped_diag_3_27',
#  'grouped_diag_3_28',
#  'grouped_diag_3_29',
#  'grouped_diag_3_30',
#  'grouped_diag_3_31',
#  'grouped_diag_3_32',
#  'grouped_diag_3_33',
#  'grouped_diag_3_34',
#  'grouped_diag_3_35',
#  'grouped_diag_3_36',
#  'grouped_diag_3_37',
#  'grouped_diag_3_38',
#  'grouped_diag_3_39',
#  'grouped_diag_3_40',
#  'grouped_diag_3_41',
#  'grouped_diag_3_42',
#  'grouped_diag_3_43',
#  'grouped_diag_3_44',
#  'grouped_diag_3_45',
#  'grouped_diag_3_46',
#  'grouped_diag_3_47',
#  'grouped_diag_3_48',
#  'grouped_diag_3_49',
#  'grouped_diag_3_50',
#  'grouped_diag_3_51',
#  'grouped_diag_3_52',
#  'grouped_diag_3_53',
#  'grouped_diag_3_54',
#  'grouped_diag_3_55',
#  'grouped_diag_3_56',
#  'grouped_diag_3_57',
#  'grouped_diag_3_58',
#  'grouped_diag_3_59',
#  'grouped_diag_3_60',
#  'grouped_diag_3_61',
#  'grouped_diag_3_62',
#  'grouped_diag_3_64',
#  'grouped_diag_3_65',
#  'grouped_diag_3_66',
#  'grouped_diag_3_67',
#  'grouped_diag_3_68',
#  'grouped_diag_3_69',
#  'grouped_diag_3_70',
#  'grouped_diag_3_71',
#  'grouped_diag_3_72',
#  'grouped_diag_3_73',
#  'grouped_diag_3_74',
#  'grouped_diag_3_75',
#  'grouped_diag_3_78',
#  'grouped_diag_3_79',
#  'grouped_diag_3_80',
#  'grouped_diag_3_81',
#  'grouped_diag_3_82',
#  'grouped_diag_3_83',
#  'grouped_diag_3_84',
#  'grouped_diag_3_85',
#  'grouped_diag_3_86',
#  'grouped_diag_3_87',
#  'grouped_diag_3_88',
#  'grouped_diag_3_89',
#  'grouped_diag_3_90',
#  'grouped_diag_3_91',
#  'grouped_diag_3_92',
#  'grouped_diag_3_93',
#  'grouped_diag_3_94',
#  'grouped_diag_3_95',
#  'grouped_diag_3_96',
#  'grouped_diag_3_97',
#  'grouped_diag_3_98',
#  'grouped_diag_3_99',
#  'grouped_diag_3_E8',
#  'grouped_diag_3_E9',
#  'grouped_diag_3_V0',
#  'grouped_diag_3_V1',
#  'grouped_diag_3_V2',
#  'grouped_diag_3_V4',
#  'grouped_diag_3_V5',
#  'grouped_diag_3_V6',
#  'grouped_diag_3_V7',
#  'grouped_diag_3_V8']

# %% [markdown]
# # Examine the class label imbalance

# %%
neg, pos = np.bincount(first_counter_OHE['readmitted_rescaled'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 70434
#     Positive: 6293 (8.93% of total)

# %% [markdown]
# # Split Data

# %%
# Use a utility from sklearn to split and shuffle our dataset.
train_df, test_df = train_test_split(first_counter_OHE, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.2)

# %%
print(test_df.shape)
print(train_df.shape)
print(val_df.shape)
# Out:
# (14087, 382)
# (45077, 382)
# (11270, 382)

# %% [markdown]
# # Distribution of Data

# %%
neg, pos = np.bincount(train_df['readmitted_rescaled'])
total = neg + pos
print('Train Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))

neg, pos = np.bincount(val_df['readmitted_rescaled'])
total = neg + pos
print('Validation Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))


neg, pos = np.bincount(test_df['readmitted_rescaled'])
total = neg + pos
print('Test Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Train Examples:
#     Total: 45077
#     Positive: 4042 (8.97% of total)
#
# Validation Examples:
#     Total: 11270
#     Positive: 961 (8.53% of total)
#
# Test Examples:
#     Total: 14087
#     Positive: 1290 (9.16% of total)

# %%
val_df.to_csv("../data/processed/validation.csv", index=False)
test_df.to_csv("../data/processed/test.csv", index=False)

# %% [markdown]
# # Upsampling-SMOTE

# %%
y_train = train_df["readmitted_rescaled"]
X_train = train_df.drop("readmitted_rescaled", axis=1)

# %%
# Instantiate SMOTE and fit
os = SMOTE(random_state=0)
columns = X_train.columns

data_X_smote, data_y_smote = os.fit_sample(X_train, y_train)
data_X_smote = pd.DataFrame(data=data_X_smote, columns=columns)
data_y_smote = pd.DataFrame(data=data_y_smote, columns=['readmitted_rescaled'])

# Check the numbers of our data
print("Length of oversampled data is ", len(data_X_smote))
print("Number of no readmissions in oversampled data",
      len(data_y_smote[data_y_smote['readmitted_rescaled'] == 0]))
print("Number of readmissions", len(
    data_y_smote[data_y_smote['readmitted_rescaled'] == 1]))
print("Proportion of no readmissions data in oversampled data is ", len(
    data_y_smote[data_y_smote['readmitted_rescaled'] == 0])/len(data_y_smote))
print("Proportion of readmissions data in oversampled data is ", len(
    data_y_smote[data_y_smote['readmitted_rescaled'] == 1])/len(data_y_smote))
# Out:
# Length of oversampled data is  82070
# Number of no readmissions in oversampled data 41035
# Number of readmissions 41035
# Proportion of no readmissions data in oversampled data is  0.5
# Proportion of readmissions data in oversampled data is  0.5

# %%
SMOTE_df = data_X_smote.join(data_y_smote)
SMOTE_df.head(5)

SMOTE_df.to_csv("../data/processed/SMOTE_df.csv", index=False)

# %% [markdown]
# # Downsampling

# %%
pos_samples = train_df[train_df['readmitted_rescaled'] == 1]
neg_samples = train_df[train_df['readmitted_rescaled'] == 0]
neg_samples = neg_samples.sample(n=len(pos_samples))

DS_train_df = pd.concat([pos_samples, neg_samples])
DS_train_df.shape
# Out:
# (8084, 382)

# %%
# Check the numbers of our data
print("Length of downsampled data is ", len(DS_train_df))
print("Number of no readmissions in oversampled data",
      len(DS_train_df[DS_train_df['readmitted_rescaled'] == 0]))
print("Number of readmissions", len(
    DS_train_df[DS_train_df['readmitted_rescaled'] == 1]))
print("Proportion of no readmissions data in oversampled data is ", len(
    DS_train_df[DS_train_df['readmitted_rescaled'] == 0])/len(DS_train_df))
print("Proportion of readmissions data in oversampled data is ", len(
    DS_train_df[DS_train_df['readmitted_rescaled'] == 1])/len(DS_train_df))
# Out:
# Length of downsampled data is  8084
# Number of no readmissions in oversampled data 4042
# Number of readmissions 4042
# Proportion of no readmissions data in oversampled data is  0.5
# Proportion of readmissions data in oversampled data is  0.5

# %%
DS_train_df.to_csv("../data/processed/DS_train_df.csv", index=False)
